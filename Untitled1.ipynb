# %%
# making a plot with simplified data
import pandas as pd
import matplotlib.pyplot as plt
# if using a Jupyter notebook, include:
# %matplotlib inline

# %%
#import students current cases data sheet
students = pd.read_csv("data/students.csv")

# %%
students.head()
# Out:
#         Location    date  solation_cases  cases_to_date  contact_notifications
# 0  Highland Park  9/5/21               7             19                    130
# 1       Richmond  9/5/21               2             13                    105
# 2   Sangre Ridge  9/5/21               3             10                    164
# 3        Skyline  9/5/21              15             21                    273
# 4       Westwood  9/5/21               5              9                    116

# %%
#make schools the index
students.Location.unique()
# Out:
# array(['Highland Park', 'Richmond', 'Sangre Ridge', 'Skyline', 'Westwood',
#        'Will Rogers', 'SMS', 'SJHS', 'SHS', 'Lincoln Academy',
#        'Virtual Academy', 'Facilities', 'Child Nutrition***',
#        'Transportation', 'Technology', 'Central Office',
#        'Other (Multiple sites)'], dtype=object)

# %%
students["date"] = pd.to_datetime(students["date"])
students["date"]
# Out:
# 0    2021-09-05
# 1    2021-09-05
# 2    2021-09-05
# 3    2021-09-05
# 4    2021-09-05
#         ...
# 80   2021-09-04
# 81   2021-09-04
# 82   2021-09-04
# 83   2021-09-04
# 84   2021-09-04
# Name: date, Length: 85, dtype: datetime64[ns]

# %%
students.head()
# Out:
#         Location       date  solation_cases  cases_to_date  \
# 0  Highland Park 2021-09-05               7             19
# 1       Richmond 2021-09-05               2             13
# 2   Sangre Ridge 2021-09-05               3             10
# 3        Skyline 2021-09-05              15             21
# 4       Westwood 2021-09-05               5              9
#
#    contact_notifications
# 0                    130
# 1                    105
# 2                    164
# 3                    273
# 4                    116

# %%
#get rid of locations that aren't schools
schools = students["Location"].isin(['Highland Park', 'Richmond', 'Sangre Ridge', 'Skyline', 'Westwood',
       'Will Rogers', 'SMS', 'SJHS', 'SHS', 'Lincoln Academy',
       'Virtual Academy'])
schools = students[schools]

# %%
schools.head()
# Out:
#         Location       date  solation_cases  cases_to_date  \
# 0  Highland Park 2021-09-05               7             19
# 1       Richmond 2021-09-05               2             13
# 2   Sangre Ridge 2021-09-05               3             10
# 3        Skyline 2021-09-05              15             21
# 4       Westwood 2021-09-05               5              9
#
#    contact_notifications
# 0                    130
# 1                    105
# 2                    164
# 3                    273
# 4                    116

# %%
isolation = schools.pivot(index="date", columns="Location", values="solation_cases")
cases = schools.pivot(index="date", columns="Location", values="cases_to_date")
notifications = schools.pivot(index="date", columns="Location", values="contact_notifications")

# %%
isolation.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
isolation_all = isolation.plot(ylabel="Student Cases in Isolation", figsize=(15,15))

# %%
isolation_all = isolation_all[0].get_figure()
isolation_all.savefig("img/students_in_isolation.png")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-53-8067ae6daf39> in <module>
# ----> 1 isolation_all = isolation_all[0].get_figure()
#       2 isolation_all.savefig("students_in_isolation.png")
#
# TypeError: 'AxesSubplot' object is not subscriptable

# %%
plt.figure();
isolation.plot(subplots=True, figsize=(5,10))
#initially used  sharey=[0,40] to make all plots have the same axis but SHS made every other school's plot a flat line
#isolation.savefig("img/students_in_isolation_subs.png")
# Out:
# array([<AxesSubplot:xlabel='date'>, <AxesSubplot:xlabel='date'>,
#        <AxesSubplot:xlabel='date'>, <AxesSubplot:xlabel='date'>,
#        <AxesSubplot:xlabel='date'>, <AxesSubplot:xlabel='date'>,
#        <AxesSubplot:xlabel='date'>, <AxesSubplot:xlabel='date'>,
#        <AxesSubplot:xlabel='date'>, <AxesSubplot:xlabel='date'>,
#        <AxesSubplot:xlabel='date'>], dtype=object)

# %%
plt.plot(isolation, subplots=True)

plt.savefig("img/students_in_isolation_subs.png")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-72-b4388d88fa49> in <module>
# ----> 1 plt.plot(isolation, subplots=True)
#       2
#       3 plt.savefig("img/students_in_isolation_subs.png")
#       4
#       5 plt.show()
#
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2838 @_copy_docstring_and_deprecators(Axes.plot)
#    2839 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2840     return gca().plot(
#    2841         *args, scalex=scalex, scaley=scaley,
#    2842         **({"data": data} if data is not None else {}), **kwargs)
#
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1741         """
#    1742         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1743         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1744         for line in lines:
#    1745             self.add_line(line)
#
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_base.py in __call__(self, data, *args, **kwargs)
#     271                 this += args[0],
#     272                 args = args[1:]
# --> 273             yield from self._plot_args(this, kwargs)
#     274
#     275     def get_next_color(self):
#
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     416         if ncx > 1 and ncy > 1 and ncx != ncy:
#     417             raise ValueError(f"x has {ncx} columns but y has {ncy} columns")
# --> 418         return [func(x[:, j % ncx], y[:, j % ncy], kw, kwargs)
#     419                 for j in range(max(ncx, ncy))]
#     420
#
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_base.py in <listcomp>(.0)
#     416         if ncx > 1 and ncy > 1 and ncx != ncy:
#     417             raise ValueError(f"x has {ncx} columns but y has {ncy} columns")
# --> 418         return [func(x[:, j % ncx], y[:, j % ncy], kw, kwargs)
#     419                 for j in range(max(ncx, ncy))]
#     420
#
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_base.py in _makeline(self, x, y, kw, kwargs)
#     310         default_dict = self._getdefaults(set(), kw)
#     311         self._setdefaults(default_dict, kw)
# --> 312         seg = mlines.Line2D(x, y, **kw)
#     313         return seg
#     314
#
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/lines.py in __init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     388         # update kwargs before updating data to give the caller a
#     389         # chance to init axes (and hence unit support)
# --> 390         self.update(kwargs)
#     391         self.pickradius = pickradius
#     392         self.ind_offset = 0
#
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/artist.py in update(self, props)
#     994                     func = getattr(self, f"set_{k}", None)
#     995                     if not callable(func):
# --> 996                         raise AttributeError(f"{type(self).__name__!r} object "
#     997                                              f"has no property {k!r}")
#     998                     ret.append(func(v))
#
# AttributeError: 'Line2D' object has no property 'subplots'

# %%
iso_fig = subs_isolation[0].get_figure()
iso_fig.savefig("img/students_in_isolation_subs.png")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-67-26c96aa610d1> in <module>
# ----> 1 iso_fig = subs_isolation[0].get_figure()
#       2 iso_fig.savefig("img/students_in_isolation_subs.png")
#
# TypeError: 'NoneType' object is not subscriptable
